# %%
import tensorflow as tf 
import keras

from keras.utils import plot_model
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split

import pickle


# %matplotlib inline

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
print(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# <tensorflow.python.client.session.Session object at 0x000002A430507E08>

# %%
"""
drawings - 0
engraving - 1 
iconography - 2 
painting - 3 
sculpture - 4 
"""

x = []
y = []

# %%
path = "../images/dataset/dataset_updated/training_set"
contador = 0

for filename in os.listdir(path):
    for filenameinterno in os.listdir(path + "/" + filename):
        x.append(cv.imread(path + "/" + filename + "/" + filenameinterno))
        y.append(contador)
    contador += 1

# %%
x_guardar = np.asarray(x)
y_guardar = np.asarray(y)

pickle.dump(x_guardar,open(r"D:\CS7\Machine Learning Models\artx.txt", "wb"))
pickle.dump(y_guardar,open(r"D:\CS7\Machine Learning Models\arty.txt", "wb"))

# %%
pre_x = pickle.load(open(r"D:\CS7\Machine Learning Models\artx.txt", "rb"))
pre_y = pickle.load(open(r"D:\CS7\Machine Learning Models\arty.txt", "rb"))

# %%
def clean_size(x,y,size):
    el = []
    for i in range(len(x)):
        if x[i] is None:
            el.append(i)
            continue
        else:
            x[i] = cv.resize(x[i],(size,size))
            x[i] = cv.cvtColor(x[i],cv.COLOR_BGR2RGB)
    x = np.array(list(np.delete(x,el)))
    y = np.delete(y,el)
    print("New shape of Dataset: ",x.shape)
    return (x,y)
    
sig_data = clean_size(pre_x,pre_y,64)
sig_x = sig_data[0]
sig_y = sig_data[1]
# Out:
# New shape of Dataset:  (8577, 64, 64, 3)

# %%
x_train,x_test,y_train,y_test = train_test_split(sig_x,sig_y,test_size=0.2,random_state=2)
x_train.shape
# Out:
# (6861, 64, 64, 3)

# %% [markdown]
# PRIMER MODELO

# %%
test1 = Sequential()

test1.add(Conv2D(32, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))

test1.add(Conv2D(64, (3,3), activation='relu'))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))

test1.add(Conv2D(128, (3,3), activation='relu'))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))


test1.add(Flatten())
test1.add(Dense(256,activation='relu'))
test1.add(Dropout(0.25))
test1.add(Dense(128,activation='relu'))
test1.add(Dense(5,activation='softmax'))

test1.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(test1.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 258,117
# Trainable params: 258,117
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
test1_train = test1.fit(x_train,y_train,
                    batch_size=32,
                    epochs=25,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/25
# 5488/5488 [==============================] - 3s 542us/step - loss: 3.6463 - accuracy: 0.4756 - val_loss: 1.3237 - val_accuracy: 0.4822
# Epoch 2/25
# 5488/5488 [==============================] - 3s 468us/step - loss: 0.9226 - accuracy: 0.6470 - val_loss: 0.9142 - val_accuracy: 0.6446
# Epoch 3/25
# 5488/5488 [==============================] - 3s 460us/step - loss: 0.8254 - accuracy: 0.6961 - val_loss: 0.8262 - val_accuracy: 0.7225
# Epoch 4/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.7518 - accuracy: 0.7278 - val_loss: 0.7309 - val_accuracy: 0.7232
# Epoch 5/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.6936 - accuracy: 0.7513 - val_loss: 0.6856 - val_accuracy: 0.7458
# Epoch 6/25
# 5488/5488 [==============================] - 3s 465us/step - loss: 0.6553 - accuracy: 0.7622 - val_loss: 0.6888 - val_accuracy: 0.7407
# Epoch 7/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.6181 - accuracy: 0.7772 - val_loss: 0.5999 - val_accuracy: 0.7830
# Epoch 8/25
# 5488/5488 [==============================] - 3s 467us/step - loss: 0.5894 - accuracy: 0.7888 - val_loss: 0.6091 - val_accuracy: 0.7691
# Epoch 9/25
# 5488/5488 [==============================] - 3s 465us/step - loss: 0.5761 - accuracy: 0.7935 - val_loss: 0.6748 - val_accuracy: 0.7524
# Epoch 10/25
# 5488/5488 [==============================] - 3s 461us/step - loss: 0.5339 - accuracy: 0.8045 - val_loss: 0.5725 - val_accuracy: 0.7917
# Epoch 11/25
# 5488/5488 [==============================] - 3s 468us/step - loss: 0.5622 - accuracy: 0.7943 - val_loss: 0.6905 - val_accuracy: 0.7458
# Epoch 12/25
# 5488/5488 [==============================] - 3s 472us/step - loss: 0.5301 - accuracy: 0.8025 - val_loss: 0.6055 - val_accuracy: 0.8034
# Epoch 13/25
# 5488/5488 [==============================] - 3s 465us/step - loss: 0.5115 - accuracy: 0.8090 - val_loss: 0.5800 - val_accuracy: 0.8012
# Epoch 14/25
# 5488/5488 [==============================] - 3s 474us/step - loss: 0.4725 - accuracy: 0.8285 - val_loss: 0.6053 - val_accuracy: 0.7881
# Epoch 15/25
# 5488/5488 [==============================] - 3s 475us/step - loss: 0.4798 - accuracy: 0.8240 - val_loss: 0.5921 - val_accuracy: 0.7881
# Epoch 16/25
# 5488/5488 [==============================] - 3s 469us/step - loss: 0.4267 - accuracy: 0.8375 - val_loss: 0.5938 - val_accuracy: 0.7822
# Epoch 17/25
# 5488/5488 [==============================] - 3s 470us/step - loss: 0.4508 - accuracy: 0.8360 - val_loss: 0.6173 - val_accuracy: 0.7844
# Epoch 18/25
# 5488/5488 [==============================] - 3s 461us/step - loss: 0.4148 - accuracy: 0.8429 - val_loss: 0.5351 - val_accuracy: 0.8114
# Epoch 19/25
# 5488/5488 [==============================] - 3s 462us/step - loss: 0.4333 - accuracy: 0.8468 - val_loss: 0.5561 - val_accuracy: 0.7997
# Epoch 20/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.4146 - accuracy: 0.8458 - val_loss: 0.5542 - val_accuracy: 0.7968
# Epoch 21/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.3788 - accuracy: 0.8641 - val_loss: 0.5607 - val_accuracy: 0.8026
# Epoch 22/25
# 5488/5488 [==============================] - 3s 464us/step - loss: 0.3661 - accuracy: 0.8675 - val_loss: 0.5808 - val_accuracy: 0.8201
# Epoch 23/25
# 5488/5488 [==============================] - 3s 473us/step - loss: 0.3432 - accuracy: 0.8723 - val_loss: 0.5446 - val_accuracy: 0.8201
# Epoch 24/25
# 5488/5488 [==============================] - 3s 472us/step - loss: 0.3544 - accuracy: 0.8730 - val_loss: 0.5194 - val_accuracy: 0.8128
# Epoch 25/25
# 5488/5488 [==============================] - 3s 461us/step - loss: 0.3476 - accuracy: 0.8695 - val_loss: 0.5531 - val_accuracy: 0.8063

# %%
# VOLVER A ABRIR EL MODELO 

test1_train = pickle.load(open(r"./models/test1_test.txt", "rb"))
test1 = load_model("./models/test1.h5")

# %%
score, acc = test1.evaluate(x_test, y_test,
                            batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)

plt.plot(test1_train.history['accuracy'], label='accuracy')
plt.plot(test1_train.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# 1716/1716 [==============================] - 1s 314us/step
# Test score: 0.9354283048278524
# Test accuracy: 0.6620046496391296

# %%
#test1.save("./models/test1.h5")
#pickle.dump(test1_train,open(r"./models/test1_test.txt", "wb"))

# %%
test2 = Sequential()

test2.add(Conv2D(64, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
test2.add(MaxPooling2D(pool_size=(2,2)))
test2.add(Dropout(0.25))

test2.add(Conv2D(64, (3,3), activation='relu'))
test2.add(MaxPooling2D(pool_size=(2,2)))
test2.add(Dropout(0.25))

test2.add(Conv2D(128, (3,3), activation='relu'))
test2.add(MaxPooling2D(pool_size=(2,2)))
test2.add(Dropout(0.25))


test2.add(Flatten())
test2.add(Dense(256,activation='relu'))
test2.add(Dense(5,activation='softmax'))

test2.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(test2.summary())
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_56 (Conv2D)           (None, 62, 62, 64)        1792
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               1179904
# _________________________________________________________________
# dense_72 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 1,293,765
# Trainable params: 1,293,765
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
test2_train = test2.fit(x_train,y_train,
                    batch_size=32,
                    epochs=25,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/25
# 5488/5488 [==============================] - 3s 619us/step - loss: 6.4280 - accuracy: 0.5078 - val_loss: 1.1051 - val_accuracy: 0.5776
# Epoch 2/25
# 5488/5488 [==============================] - 3s 551us/step - loss: 0.9338 - accuracy: 0.6534 - val_loss: 0.9805 - val_accuracy: 0.6744
# Epoch 3/25
# 5488/5488 [==============================] - 3s 553us/step - loss: 0.8246 - accuracy: 0.6979 - val_loss: 0.8398 - val_accuracy: 0.6992
# Epoch 4/25
# 5488/5488 [==============================] - 3s 557us/step - loss: 0.7262 - accuracy: 0.7363 - val_loss: 0.7518 - val_accuracy: 0.7553
# Epoch 5/25
# 5488/5488 [==============================] - 3s 555us/step - loss: 0.6731 - accuracy: 0.7618 - val_loss: 0.7517 - val_accuracy: 0.7349
# Epoch 6/25
# 5488/5488 [==============================] - 3s 553us/step - loss: 0.6053 - accuracy: 0.7810 - val_loss: 0.7245 - val_accuracy: 0.7210
# Epoch 7/25
# 5488/5488 [==============================] - 3s 554us/step - loss: 0.5713 - accuracy: 0.7934 - val_loss: 0.6238 - val_accuracy: 0.7822
# Epoch 8/25
# 5488/5488 [==============================] - 3s 559us/step - loss: 0.5535 - accuracy: 0.8001 - val_loss: 0.7113 - val_accuracy: 0.7633
# Epoch 9/25
# 5488/5488 [==============================] - 3s 555us/step - loss: 0.5027 - accuracy: 0.8123 - val_loss: 0.5959 - val_accuracy: 0.7888
# Epoch 10/25
# 5488/5488 [==============================] - 3s 558us/step - loss: 0.4722 - accuracy: 0.8285 - val_loss: 0.6856 - val_accuracy: 0.7589
# Epoch 11/25
# 5488/5488 [==============================] - 3s 563us/step - loss: 0.4474 - accuracy: 0.8322 - val_loss: 0.6630 - val_accuracy: 0.7669
# Epoch 12/25
# 5488/5488 [==============================] - 3s 559us/step - loss: 0.4508 - accuracy: 0.8313 - val_loss: 0.6233 - val_accuracy: 0.7859
# Epoch 13/25
# 5488/5488 [==============================] - 3s 561us/step - loss: 0.4190 - accuracy: 0.8340 - val_loss: 0.5383 - val_accuracy: 0.8084
# Epoch 14/25
# 5488/5488 [==============================] - 3s 560us/step - loss: 0.4141 - accuracy: 0.8469 - val_loss: 0.6737 - val_accuracy: 0.7800
# Epoch 15/25
# 5488/5488 [==============================] - 3s 557us/step - loss: 0.3768 - accuracy: 0.8575 - val_loss: 0.6568 - val_accuracy: 0.7932
# Epoch 16/25
# 5488/5488 [==============================] - 3s 557us/step - loss: 0.3835 - accuracy: 0.8590 - val_loss: 0.5845 - val_accuracy: 0.7881
# Epoch 17/25
# 5488/5488 [==============================] - 3s 561us/step - loss: 0.3381 - accuracy: 0.8779 - val_loss: 0.6282 - val_accuracy: 0.7895
# Epoch 18/25
# 5488/5488 [==============================] - 3s 562us/step - loss: 0.3405 - accuracy: 0.8723 - val_loss: 0.6562 - val_accuracy: 0.8055
# Epoch 19/25
# 5488/5488 [==============================] - 3s 553us/step - loss: 0.3538 - accuracy: 0.8719 - val_loss: 0.6768 - val_accuracy: 0.7851
# Epoch 20/25
# 5488/5488 [==============================] - 3s 556us/step - loss: 0.3380 - accuracy: 0.8785 - val_loss: 0.7818 - val_accuracy: 0.7873
# Epoch 21/25
# 5488/5488 [==============================] - 3s 559us/step - loss: 0.3322 - accuracy: 0.8836 - val_loss: 0.7490 - val_accuracy: 0.8026
# Epoch 22/25
# 5488/5488 [==============================] - 3s 553us/step - loss: 0.3207 - accuracy: 0.8812 - val_loss: 0.6979 - val_accuracy: 0.7837
# Epoch 23/25
# 5488/5488 [==============================] - 3s 562us/step - loss: 0.2946 - accuracy: 0.8898 - val_loss: 0.6431 - val_accuracy: 0.7917
# Epoch 24/25
# 5488/5488 [==============================] - 3s 552us/step - loss: 0.2490 - accuracy: 0.9122 - val_loss: 0.6227 - val_accuracy: 0.7924
# Epoch 25/25
# 5488/5488 [==============================] - 3s 552us/step - loss: 0.2657 - accuracy: 0.8969 - val_loss: 0.7649 - val_accuracy: 0.8034

# %%
test2.save("./models/test2.h5")
pickle.dump(test2_train,open(r"./models/test2_test.txt", "wb"))

# %%
score, acc = test2.evaluate(x_test, y_test,
                            batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)

plt.plot(test2_train.history['accuracy'], label='accuracy')
plt.plot(test2_train.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
# Out:
# 1716/1716 [==============================] - 0s 264us/step
# Test score: 0.797521742073806
# Test accuracy: 0.7937062978744507

# %%
# data augmentation test 

generador = ImageDataGenerator(width_shift_range=0.2,
                              height_shift_range=0.2,
                              rotation_range=25)
iterador = generador.flow(x_train,y_train, batch_size=32)

# %%
modelo = Sequential()

modelo.add(Conv2D(128, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
modelo.add(Conv2D(128, (3,3), activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2,2)))
modelo.add(Dropout(0.25))

modelo.add(Conv2D(64, (3,3), activation='relu'))
modelo.add(Conv2D(64, (3,3), activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2,2)))
modelo.add(Dropout(0.25))

modelo.add(Conv2D(32, (3,3), activation='relu'))
modelo.add(Dropout(0.25))

modelo.add(Flatten())
modelo.add(Dense(128,activation='relu'))
modelo.add(Dropout(0.25))
modelo.add(Dense(64,activation='relu'))
modelo.add(Dense(5,activation='softmax'))

modelo.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(modelo.summary())
# Out:
# Model: "sequential_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_257 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_258 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_148 (MaxPoolin (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_241 (Dropout)        (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_259 (Conv2D)          (None, 12, 12, 64)        73792
# _________________________________________________________________
# conv2d_260 (Conv2D)          (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_149 (MaxPoolin (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_242 (Dropout)        (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_261 (Conv2D)          (None, 3, 3, 32)          18464
# _________________________________________________________________
# dropout_243 (Dropout)        (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten_66 (Flatten)         (None, 288)               0
# _________________________________________________________________
# dense_212 (Dense)            (None, 128)               36992
# _________________________________________________________________
# dropout_244 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_213 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_214 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 325,925
# Trainable params: 325,925
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
modelo_train = modelo.fit(x_train,y_train,
                    batch_size=64,
                    epochs=65,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/65
# 5488/5488 [==============================] - 3s 468us/step - loss: 1.7604 - accuracy: 0.2648 - val_loss: 1.3716 - val_accuracy: 0.3693
# Epoch 2/65
# 5488/5488 [==============================] - 2s 385us/step - loss: 1.3480 - accuracy: 0.4308 - val_loss: 1.2621 - val_accuracy: 0.5310
# Epoch 3/65
# 5488/5488 [==============================] - 2s 387us/step - loss: 1.2118 - accuracy: 0.5301 - val_loss: 1.1127 - val_accuracy: 0.5747
# Epoch 4/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 1.0894 - accuracy: 0.5774 - val_loss: 1.0465 - val_accuracy: 0.5958
# Epoch 5/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 1.0527 - accuracy: 0.5835 - val_loss: 0.9999 - val_accuracy: 0.6133
# Epoch 6/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 1.0136 - accuracy: 0.5958 - val_loss: 0.9940 - val_accuracy: 0.5972
# Epoch 7/65
# 5488/5488 [==============================] - 2s 393us/step - loss: 0.9885 - accuracy: 0.6040 - val_loss: 0.9932 - val_accuracy: 0.6125
# Epoch 8/65
# 5488/5488 [==============================] - 2s 394us/step - loss: 0.9502 - accuracy: 0.6130 - val_loss: 0.9983 - val_accuracy: 0.6023
# Epoch 9/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.9362 - accuracy: 0.6286 - val_loss: 0.9523 - val_accuracy: 0.5921
# Epoch 10/65
# 5488/5488 [==============================] - 2s 394us/step - loss: 0.9529 - accuracy: 0.6239 - val_loss: 0.8994 - val_accuracy: 0.6460
# Epoch 11/65
# 5488/5488 [==============================] - 2s 393us/step - loss: 0.8829 - accuracy: 0.6633 - val_loss: 0.8518 - val_accuracy: 0.6788
# Epoch 12/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.8687 - accuracy: 0.6647 - val_loss: 0.9021 - val_accuracy: 0.6642
# Epoch 13/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.8158 - accuracy: 0.6879 - val_loss: 0.8010 - val_accuracy: 0.6795
# Epoch 14/65
# 5488/5488 [==============================] - 2s 393us/step - loss: 0.8131 - accuracy: 0.6942 - val_loss: 0.8327 - val_accuracy: 0.6832
# Epoch 15/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.7635 - accuracy: 0.7121 - val_loss: 0.7423 - val_accuracy: 0.7240
# Epoch 16/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.7488 - accuracy: 0.7075 - val_loss: 0.7473 - val_accuracy: 0.7189
# Epoch 17/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.7381 - accuracy: 0.7199 - val_loss: 0.8512 - val_accuracy: 0.6956
# Epoch 18/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.7408 - accuracy: 0.7216 - val_loss: 0.7313 - val_accuracy: 0.7291
# Epoch 19/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.7018 - accuracy: 0.7334 - val_loss: 0.7179 - val_accuracy: 0.7189
# Epoch 20/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.6914 - accuracy: 0.7369 - val_loss: 0.7386 - val_accuracy: 0.7385
# Epoch 21/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.6769 - accuracy: 0.7507 - val_loss: 0.7393 - val_accuracy: 0.7327
# Epoch 22/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.6713 - accuracy: 0.7427 - val_loss: 0.7035 - val_accuracy: 0.7189
# Epoch 23/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.6390 - accuracy: 0.7538 - val_loss: 0.6914 - val_accuracy: 0.7509
# Epoch 24/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.6163 - accuracy: 0.7608 - val_loss: 0.6664 - val_accuracy: 0.7495
# Epoch 25/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.6033 - accuracy: 0.7697 - val_loss: 0.6905 - val_accuracy: 0.7444
# Epoch 26/65
# 5488/5488 [==============================] - 2s 393us/step - loss: 0.5948 - accuracy: 0.7766 - val_loss: 0.6905 - val_accuracy: 0.7495
# Epoch 27/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.5849 - accuracy: 0.7761 - val_loss: 0.7576 - val_accuracy: 0.7298
# Epoch 28/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.5686 - accuracy: 0.7894 - val_loss: 0.6763 - val_accuracy: 0.7487
# Epoch 29/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.5401 - accuracy: 0.7974 - val_loss: 0.6684 - val_accuracy: 0.7553
# Epoch 30/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.5573 - accuracy: 0.7921 - val_loss: 0.6344 - val_accuracy: 0.7633
# Epoch 31/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.5586 - accuracy: 0.7945 - val_loss: 0.6302 - val_accuracy: 0.7662
# Epoch 32/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.5257 - accuracy: 0.8001 - val_loss: 0.6746 - val_accuracy: 0.7509
# Epoch 33/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.5386 - accuracy: 0.7965 - val_loss: 0.7846 - val_accuracy: 0.7254
# Epoch 34/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.5359 - accuracy: 0.7965 - val_loss: 0.6525 - val_accuracy: 0.7677
# Epoch 35/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.5019 - accuracy: 0.8058 - val_loss: 0.6086 - val_accuracy: 0.7793
# Epoch 36/65
# 5488/5488 [==============================] - 2s 386us/step - loss: 0.4975 - accuracy: 0.8063 - val_loss: 0.6165 - val_accuracy: 0.7713
# Epoch 37/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.5034 - accuracy: 0.8085 - val_loss: 0.6045 - val_accuracy: 0.7793
# Epoch 38/65
# 5488/5488 [==============================] - 2s 387us/step - loss: 0.4716 - accuracy: 0.8209 - val_loss: 0.6304 - val_accuracy: 0.7655
# Epoch 39/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.4622 - accuracy: 0.8258 - val_loss: 0.6312 - val_accuracy: 0.7749
# Epoch 40/65
# 5488/5488 [==============================] - 2s 396us/step - loss: 0.4484 - accuracy: 0.8340 - val_loss: 0.5960 - val_accuracy: 0.7706
# Epoch 41/65
# 5488/5488 [==============================] - 2s 384us/step - loss: 0.4579 - accuracy: 0.8249 - val_loss: 0.5985 - val_accuracy: 0.7939
# Epoch 42/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.4504 - accuracy: 0.8298 - val_loss: 0.6117 - val_accuracy: 0.7786
# Epoch 43/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.4388 - accuracy: 0.8265 - val_loss: 0.6011 - val_accuracy: 0.7866
# Epoch 44/65
# 5488/5488 [==============================] - 2s 387us/step - loss: 0.4369 - accuracy: 0.8335 - val_loss: 0.6631 - val_accuracy: 0.7684
# Epoch 45/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.4292 - accuracy: 0.8329 - val_loss: 0.6177 - val_accuracy: 0.7749
# Epoch 46/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.4253 - accuracy: 0.8369 - val_loss: 0.6544 - val_accuracy: 0.7786
# Epoch 47/65
# 5488/5488 [==============================] - 2s 387us/step - loss: 0.4274 - accuracy: 0.8382 - val_loss: 0.6017 - val_accuracy: 0.7779
# Epoch 48/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.4027 - accuracy: 0.8462 - val_loss: 0.6185 - val_accuracy: 0.7837
# Epoch 49/65
# 5488/5488 [==============================] - 2s 391us/step - loss: 0.4188 - accuracy: 0.8438 - val_loss: 0.6107 - val_accuracy: 0.7757
# Epoch 50/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.3883 - accuracy: 0.8530 - val_loss: 0.6355 - val_accuracy: 0.7822
# Epoch 51/65
# 5488/5488 [==============================] - 2s 386us/step - loss: 0.3905 - accuracy: 0.8524 - val_loss: 0.6202 - val_accuracy: 0.7910
# Epoch 52/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.3804 - accuracy: 0.8540 - val_loss: 0.6586 - val_accuracy: 0.7742
# Epoch 53/65
# 5488/5488 [==============================] - 2s 394us/step - loss: 0.3912 - accuracy: 0.8493 - val_loss: 0.6124 - val_accuracy: 0.7895
# Epoch 54/65
# 5488/5488 [==============================] - 2s 387us/step - loss: 0.3441 - accuracy: 0.8661 - val_loss: 0.6639 - val_accuracy: 0.7844
# Epoch 55/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.3822 - accuracy: 0.8610 - val_loss: 0.6239 - val_accuracy: 0.7793
# Epoch 56/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.3796 - accuracy: 0.8526 - val_loss: 0.6167 - val_accuracy: 0.7866
# Epoch 57/65
# 5488/5488 [==============================] - 2s 392us/step - loss: 0.3721 - accuracy: 0.8621 - val_loss: 0.6325 - val_accuracy: 0.7881
# Epoch 58/65
# 5488/5488 [==============================] - 2s 388us/step - loss: 0.3620 - accuracy: 0.8646 - val_loss: 0.6593 - val_accuracy: 0.7837
# Epoch 59/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.3635 - accuracy: 0.8590 - val_loss: 0.6852 - val_accuracy: 0.7757
# Epoch 60/65
# 5488/5488 [==============================] - 2s 383us/step - loss: 0.3422 - accuracy: 0.8701 - val_loss: 0.6226 - val_accuracy: 0.8004
# Epoch 61/65
# 5488/5488 [==============================] - 2s 390us/step - loss: 0.3588 - accuracy: 0.8619 - val_loss: 0.6224 - val_accuracy: 0.7939
# Epoch 62/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.3504 - accuracy: 0.8681 - val_loss: 0.6815 - val_accuracy: 0.7691
# Epoch 63/65
# 5488/5488 [==============================] - 2s 389us/step - loss: 0.3399 - accuracy: 0.8632 - val_loss: 0.6355 - val_accuracy: 0.7808
# Epoch 64/65
# 5488/5488 [==============================] - 2s 386us/step - loss: 0.3130 - accuracy: 0.8806 - val_loss: 0.6623 - val_accuracy: 0.8048
# Epoch 65/65
# 5488/5488 [==============================] - 2s 386us/step - loss: 0.3205 - accuracy: 0.8797 - val_loss: 0.6679 - val_accuracy: 0.7786

# %%
score, acc = modelo.evaluate(x_test, y_test,
                            batch_size=64)
print('Test score:', score)
print('Test accuracy:', acc)

plt.plot(modelo_train.history['accuracy'], label='accuracy')
plt.plot(modelo_train.history['val_accuracy'], label = 'val_accuracy')
plt.plot(modelo_train.history['loss'], label = 'loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.2, 1])
plt.legend(loc='lower left')
# Out:
# 1716/1716 [==============================] - 0s 135us/step
# Test score: 0.6727404551350431
# Test accuracy: 0.806526780128479

# %%
test2.save("./models/test3.h5")
pickle.dump(modelo_train,open(r"./models/test3_test.txt", "wb"))

# %%
generador_data = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.1,
    brightness_range=[0.2,1.0]
)

# %%
iterador = generador_data.flow(x_train,y_train, batch_size=32)

# %%
imagenes = [next(iterador)[0].astype(np.uint8) for i in range(5)]
type(imagenes[0])
# Out:
# numpy.ndarray

# %%
plt.imshow(imagenes[0][6,:,:])

# %%
test1 = Sequential()

test1.add(Conv2D(128, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
test1.add(Conv2D(128, (3,3), activation='relu'))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))

test1.add(Conv2D(64, (3,3), activation='relu'))
test1.add(Conv2D(64, (3,3), activation='relu'))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))

test1.add(Conv2D(32, (3,3), activation='relu'))
test1.add(MaxPooling2D(pool_size=(2,2)))
test1.add(Dropout(0.25))

test1.add(Flatten())
test1.add(Dense(128,activation='relu'))
test1.add(Dropout(0.25))
test1.add(Dense(64,activation='relu'))
test1.add(Dense(5,activation='softmax'))

test1.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(test1.summary())
# Out:
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_269 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_270 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_155 (MaxPoolin (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_252 (Dropout)        (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_271 (Conv2D)          (None, 12, 12, 64)        73792
# _________________________________________________________________
# conv2d_272 (Conv2D)          (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_156 (MaxPoolin (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_253 (Dropout)        (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_273 (Conv2D)          (None, 3, 3, 32)          18464
# _________________________________________________________________
# max_pooling2d_157 (MaxPoolin (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout_254 (Dropout)        (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_69 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_221 (Dense)            (None, 128)               4224
# _________________________________________________________________
# dropout_255 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_222 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_223 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 293,157
# Trainable params: 293,157
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# PROBAR EL MODELO

# %%
modelo_final = load_model(r"./models/test3.h5")

# %%
posibilidades = ['drawing','engraving','iconography','painting','sculpture']
for i in range(8):
    number = np.random.randint(1,1500)
    test_image = x_test[number]
    transformed = cv.resize(test_image,(64,64))
    plt.imshow(cv.cvtColor(test_image,cv.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
    print("GUESS: ",posibilidades[np.argmax(modelo_final.predict(np.expand_dims(transformed,0)))])
    print("REAL: ", posibilidades[y_test[number]])
# Out:
# GUESS:  sculpture
# REAL:  engraving
# GUESS:  sculpture
# REAL:  painting
# GUESS:  sculpture
# REAL:  iconography
# GUESS:  sculpture
# REAL:  iconography
# GUESS:  drawing
# REAL:  painting
# GUESS:  drawing
# REAL:  engraving
# GUESS:  sculpture
# REAL:  iconography
# GUESS:  sculpture
# REAL:  painting

# %%
np.unique(pruebay,return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([1229,  844, 2310, 2364, 1938], dtype=int64))

# %%
filtros = []
for i in fourth.layers:
    if "conv" not in i.name:
        continue
    filters,bias = i.get_weights()
    filtros.append(filters)
    print(filters.shape)
# Out:
# (3, 3, 3, 128)
# (3, 3, 128, 64)
# (3, 3, 64, 64)
# (3, 3, 64, 32)
# (3, 3, 32, 32)

# %%
filters = filtros[0]
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
plt.imshow(filters[:,:,:,0][:,:,0],cmap='gray')

# %%
from keras.models import Model
#feature_model = Model(inputs=fourth.inputs, outputs=fourth.layers[2].output)

# %%
feature_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_158_input (InputLayer (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d_108 (MaxPoolin (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 15, 15, 128)       0
# =================================================================
# Total params: 3,584
# Trainable params: 3,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = feature_model.predict(np.expand_dims(cv.resize(cv.imread('./test.jpg'),(32,32)),0))

# %%
result.shape
# Out:
# (1, 15, 15, 128)

# %%
for i in range(128):
    plt.imshow(result[0,:,:,i],cmap="gray")
    plt.axis("off")
    plt.show()

# %%
from keras.models import load_model
ver = load_model("./fourth.h5")

# %%
outputs = []
for i in range(len(fourth2.layers)):
    if 'conv' in fourth2.layers[i].name:
        conv.append(fourth2.layers[i])
        print(i)
# Out:
# 0
# 3
# 4
# 7
# 8

# %%
sacar = Model(inputs=fourth2.inputs, outputs=fourth2.layers[0].output)

# %%
test = cv.imread('./test.jpg')
test = cv.cvtColor(test,cv.COLOR_BGR2RGB)
test = np.expand_dims(cv.resize(test,(64,64)),0)
test.shape
# Out:
# (1, 64, 64, 3)

# %%
features = sacar.predict(test)

# %%
features.shape
# Out:
# (1, 62, 62, 128)

# %%
for i in range(0,127):
    temp = features[0,:,:,i]
    plt.imshow(temp,cmap='gray')
    plt.show()
