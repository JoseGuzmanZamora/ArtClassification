# %%
import tensorflow as tf 
import keras
from keras.utils import plot_model
import cv2 as cv
import matplotlib.pyplot as plt



# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
print(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# <tensorflow.python.client.session.Session object at 0x0000020D116BCC88>

# %%
img = cv.imread("./21.jpg")
img2 = cv.imread("./0272.jpg")
img2 = cv.cvtColor(img2,cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
plt.imshow(img2)

# %%
x = []
y = []

# %%
"""
drawings - 0
engraving - 1 
iconography - 2 
painting - 3 
sculpture - 4 
"""
# Out:
# '\ndrawings - 0\nengraving - 1 \niconography - 2 \npainting - 3 \nsculpture - 4 \n'

# %%
import os
import pickle
import numpy as np

# %%
path = "../images/dataset/dataset_updated/training_set"
contador = 0
contador2 = 0

# %%
for filename in os.listdir(path):
    #x.append(cv.imread(path + "/" + filename))
    #y.append()
    for filenameinterno in os.listdir(path + "/" + filename):
        x.append(cv.imread(path + "/" + filename + "/" + filenameinterno))
        y.append(contador)
    contador += 1

# %%
deb = 0
for filename in os.listdir(path):
    for filenameinterno in os.listdir(path + "/" + filename):
        deb += 1
        if deb == 1210:
            print(filenameinterno)
    contador += 1
# Out:
# 249.jpg

# %%
x_guardar = np.asarray(x)
y_guardar = np.asarray(y)

# %%
pickle.dump(x_guardar,open(r"D:\CS7\Machine Learning Models\artx.txt", "wb"))
pickle.dump(y_guardar,open(r"D:\CS7\Machine Learning Models\arty.txt", "wb"))

# %%
pruebax = pickle.load(open(r"D:\CS7\Machine Learning Models\artx.txt", "rb"))
pruebay = pickle.load(open(r"D:\CS7\Machine Learning Models\arty.txt", "rb"))

# %%
min1 = 20000
min2 = 20000
el = []

for i in range(len(pruebax)):
    if pruebax[i] is None:
        el.append(i)
        continue
    else:
        pruebax[i] = cv.resize(prueba[i],(32,32))
        pruebax[i] = cv.cvtColor(img2,cv.COLOR_BGR2RGB)

# %%
pruebax = np.delete(pruebax,el)

# %%
pruebay = np.delete(pruebay,el)

# %%
pruebax = np.array(list(pruebax))

# %%
pruebax.shape
# Out:
# (8577, 244, 290, 3)

# %%
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
first = Sequential()

first.add(Conv2D(64, (3,3), activation='relu', input_shape=(pruebax.shape[1:])))
first.add(MaxPooling2D(pool_size=(2,2)))
first.add(Dropout(0.25))

first.add(Conv2D(64, (3,3), activation='relu'))
first.add(MaxPooling2D(pool_size=(2,2)))

first.add(Flatten())
first.add(Dense(128,activation='relu'))
first.add(Dense(5,activation='softmax'))

first.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(first.summary())
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 242, 288, 64)      1792
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 121, 144, 64)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 121, 144, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 119, 142, 64)      36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 59, 71, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 268096)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               34316416
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 34,355,781
# Trainable params: 34,355,781
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
entrenar = first.fit(pruebax,pruebay,
                    batch_size=32,
                    epochs=5,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 6861 samples, validate on 1716 samples
# Epoch 1/5
# 6861/6861 [==============================] - 46s 7ms/step - loss: inf - accuracy: 0.2889 - val_loss: 1.6582 - val_accuracy: 0.1346
# Epoch 2/5
# 6861/6861 [==============================] - 44s 6ms/step - loss: 1.5495 - accuracy: 0.2982 - val_loss: 1.7053 - val_accuracy: 0.1346
# Epoch 3/5
# 6861/6861 [==============================] - 44s 6ms/step - loss: 1.5346 - accuracy: 0.2954 - val_loss: 1.7406 - val_accuracy: 0.1346
# Epoch 4/5
# 6861/6861 [==============================] - 44s 6ms/step - loss: 1.5282 - accuracy: 0.3027 - val_loss: 1.7664 - val_accuracy: 0.1346
# Epoch 5/5
# 6861/6861 [==============================] - 44s 6ms/step - loss: 1.5255 - accuracy: 0.3027 - val_loss: 1.7842 - val_accuracy: 0.1346
