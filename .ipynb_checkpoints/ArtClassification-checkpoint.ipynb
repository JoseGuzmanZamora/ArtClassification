# %%
import tensorflow as tf 
import keras
from keras.utils import plot_model
import cv2 as cv
import matplotlib.pyplot as plt



# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
print(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# <tensorflow.python.client.session.Session object at 0x00000252433E4F08>

# %%
x = []
y = []

# %%
"""
drawings - 0
engraving - 1 
iconography - 2 
painting - 3 
sculpture - 4 
"""
# Out:
# '\ndrawings - 0\nengraving - 1 \niconography - 2 \npainting - 3 \nsculpture - 4 \n'

# %%
import os
import pickle
import numpy as np

# %%
path = "../images/dataset/dataset_updated/training_set"
contador = 0
contador2 = 0

# %%
for filename in os.listdir(path):
    #x.append(cv.imread(path + "/" + filename))
    #y.append()
    for filenameinterno in os.listdir(path + "/" + filename):
        x.append(cv.imread(path + "/" + filename + "/" + filenameinterno))
        y.append(contador)
    contador += 1

# %%
deb = 0
for filename in os.listdir(path):
    for filenameinterno in os.listdir(path + "/" + filename):
        deb += 1
        if deb == 1210:
            print(filenameinterno)
    contador += 1
# Out:
# 249.jpg

# %%
x_guardar = np.asarray(x)
y_guardar = np.asarray(y)

# %%
pickle.dump(x_guardar,open(r"D:\CS7\Machine Learning Models\artx.txt", "wb"))
pickle.dump(y_guardar,open(r"D:\CS7\Machine Learning Models\arty.txt", "wb"))

# %%
pruebax = pickle.load(open(r"D:\CS7\Machine Learning Models\artx.txt", "rb"))
pruebay = pickle.load(open(r"D:\CS7\Machine Learning Models\arty.txt", "rb"))

# %%
el = []

for i in range(len(pruebax)):
    if pruebax[i] is None:
        el.append(i)
        continue
    else:
        pruebax[i] = cv.resize(pruebax[i],(64,64))
        #pruebax[i] = cv.cvtColor(pruebax[i],cv.COLOR_BGR2RGB)

# %%
pruebax = np.delete(pruebax,el)

# %%
pruebay = np.delete(pruebay,el)

# %%
pruebax = np.array(list(pruebax))

# %%
pruebax.shape
# Out:
# (8577, 64, 64, 3)

# %%
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(pruebax,pruebay,test_size=0.2,random_state=2)
print(x_train[0].shape)
# Out:
# (64, 64, 3)

# %%
second = Sequential()

second.add(Conv2D(32, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
second.add(MaxPooling2D(pool_size=(2,2)))
second.add(Dropout(0.25))

second.add(Conv2D(64, (3,3), activation='relu'))
second.add(MaxPooling2D(pool_size=(2,2)))
second.add(Dropout(0.25))

second.add(Conv2D(128, (3,3), activation='relu'))
second.add(MaxPooling2D(pool_size=(2,2)))
second.add(Dropout(0.25))


second.add(Flatten())
second.add(Dense(256,activation='relu'))
second.add(Dense(512,activation='relu'))
second.add(Dense(512,activation='relu'))
second.add(Dense(256,activation='relu'))
second.add(Dense(5,activation='softmax'))

second.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(second.summary())
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_49 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_50 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_51 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_52 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 751,429
# Trainable params: 751,429
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
entrenar2 = second.fit(x_train,y_train,
                    batch_size=32,
                    epochs=25,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/25
# 5488/5488 [==============================] - 2s 275us/step - loss: 0.9733 - accuracy: 0.6221 - val_loss: 1.0511 - val_accuracy: 0.5645
# Epoch 2/25
# 5488/5488 [==============================] - 1s 228us/step - loss: 0.9293 - accuracy: 0.6463 - val_loss: 0.9611 - val_accuracy: 0.6336
# Epoch 3/25
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.9170 - accuracy: 0.6481 - val_loss: 1.0013 - val_accuracy: 0.5914
# Epoch 4/25
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.9054 - accuracy: 0.6514 - val_loss: 1.0234 - val_accuracy: 0.5696
# Epoch 5/25
# 5488/5488 [==============================] - 1s 228us/step - loss: 0.8763 - accuracy: 0.6720 - val_loss: 1.0045 - val_accuracy: 0.5892
# Epoch 6/25
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.8744 - accuracy: 0.6742 - val_loss: 1.0545 - val_accuracy: 0.5878
# Epoch 7/25
# 5488/5488 [==============================] - 1s 227us/step - loss: 0.8516 - accuracy: 0.6857 - val_loss: 0.9462 - val_accuracy: 0.6366
# Epoch 8/25
# 5488/5488 [==============================] - 1s 223us/step - loss: 0.8536 - accuracy: 0.6762 - val_loss: 0.9056 - val_accuracy: 0.6555
# Epoch 9/25
# 5488/5488 [==============================] - 1s 232us/step - loss: 0.8264 - accuracy: 0.6972 - val_loss: 0.9147 - val_accuracy: 0.6526
# Epoch 10/25
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.8286 - accuracy: 0.6886 - val_loss: 0.9775 - val_accuracy: 0.6198
# Epoch 11/25
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.7958 - accuracy: 0.7013 - val_loss: 1.0950 - val_accuracy: 0.5557
# Epoch 12/25
# 5488/5488 [==============================] - 1s 224us/step - loss: 0.8046 - accuracy: 0.6966 - val_loss: 0.8876 - val_accuracy: 0.6795
# Epoch 13/25
# 5488/5488 [==============================] - 1s 228us/step - loss: 0.7823 - accuracy: 0.7057 - val_loss: 0.8697 - val_accuracy: 0.6650
# Epoch 14/25
# 5488/5488 [==============================] - 1s 223us/step - loss: 0.7846 - accuracy: 0.7057 - val_loss: 0.8500 - val_accuracy: 0.6839
# Epoch 15/25
# 5488/5488 [==============================] - 1s 221us/step - loss: 0.7786 - accuracy: 0.7174 - val_loss: 0.8817 - val_accuracy: 0.6744
# Epoch 16/25
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.7619 - accuracy: 0.7170 - val_loss: 0.8579 - val_accuracy: 0.6599
# Epoch 17/25
# 5488/5488 [==============================] - 1s 227us/step - loss: 0.7474 - accuracy: 0.7194 - val_loss: 0.8977 - val_accuracy: 0.6599
# Epoch 18/25
# 5488/5488 [==============================] - 1s 221us/step - loss: 0.7486 - accuracy: 0.7252 - val_loss: 1.0386 - val_accuracy: 0.6307
# Epoch 19/25
# 5488/5488 [==============================] - 1s 227us/step - loss: 0.7390 - accuracy: 0.7289 - val_loss: 0.8370 - val_accuracy: 0.6956
# Epoch 20/25
# 5488/5488 [==============================] - 1s 223us/step - loss: 0.7399 - accuracy: 0.7208 - val_loss: 0.8177 - val_accuracy: 0.6934
# Epoch 21/25
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.7367 - accuracy: 0.7309 - val_loss: 0.8465 - val_accuracy: 0.6926
# Epoch 22/25
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.7182 - accuracy: 0.7340 - val_loss: 0.7698 - val_accuracy: 0.7167
# Epoch 23/25
# 5488/5488 [==============================] - 1s 234us/step - loss: 0.7228 - accuracy: 0.7310 - val_loss: 0.8278 - val_accuracy: 0.6868
# Epoch 24/25
# 5488/5488 [==============================] - 1s 228us/step - loss: 0.7165 - accuracy: 0.7387 - val_loss: 0.8573 - val_accuracy: 0.6664
# Epoch 25/25
# 5488/5488 [==============================] - 1s 218us/step - loss: 0.7067 - accuracy: 0.7429 - val_loss: 0.8698 - val_accuracy: 0.6642

# %%
second.save("./second.h5")

# %%
third = Sequential()

third.add(Conv2D(64, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
third.add(MaxPooling2D(pool_size=(2,2)))
third.add(Dropout(0.25))

third.add(Conv2D(64, (3,3), activation='relu'))
third.add(MaxPooling2D(pool_size=(2,2)))
third.add(Dropout(0.25))

third.add(Conv2D(128, (3,3), activation='relu'))
third.add(MaxPooling2D(pool_size=(2,2)))
third.add(Dropout(0.25))


third.add(Flatten())
third.add(Dense(256,activation='relu'))
third.add(Dense(512,activation='relu'))
third.add(Dense(512,activation='relu'))
third.add(Dense(512,activation='relu'))
third.add(Dense(512,activation='relu'))
third.add(Dense(256,activation='relu'))
third.add(Dense(5,activation='softmax'))

third.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(third.summary())
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_60 (Conv2D)           (None, 30, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_66 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_67 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_68 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_69 (Dense)             (None, 512)               262656
# _________________________________________________________________
#
# 5488/5488 [==============================] - 1s 265us/step - loss: 0.5321 - accuracy: 0.8016 - val_loss: 0.5919 - val_accuracy: 0.7939
# Epoch 38/50
# 5488/5488 [==============================] - 1s 261us/step - loss: 0.5168 - accuracy: 0.8065 - val_loss: 0.6676 - val_accuracy: 0.7575
# Epoch 39/50
# 5488/5488 [==============================] - 1s 264us/step - loss: 0.5181 - accuracy: 0.8032 - val_loss: 0.5800 - val_accuracy: 0.7873
# Epoch 40/50
# 5488/5488 [==============================] - 1s 264us/step - loss: 0.5049 - accuracy: 0.8078 - val_loss: 0.5799 - val_accuracy: 0.7932
# Epoch 41/50
# 5488/5488 [==============================] - 1s 260us/step - loss: 0.4984 - accuracy: 0.8158 - val_loss: 0.6329 - val_accuracy: 0.7626
# Epoch 42/50
# 5488/5488 [==============================] - 1s 263us/step - loss: 0.5000 - accuracy: 0.8174 - val_loss: 0.6366 - val_accuracy: 0.7728
# Epoch 43/50
# 5488/5488 [==============================] - 1s 269us/step - loss: 0.4994 - accuracy: 0.8118 - val_loss: 0.5898 - val_accuracy: 0.7851
# Epoch 44/50
# 5488/5488 [==============================] - 1s 262us/step - loss: 0.4869 - accuracy: 0.8205 - val_loss: 0.6602 - val_accuracy: 0.7546
# Epoch 45/50
# 5488/5488 [==============================] - 1s 260us/step - loss: 0.4915 - accuracy: 0.8207 - val_loss: 0.5971 - val_accuracy: 0.7910
# Epoch 46/50
# 5488/5488 [==============================] - 1s 269us/step - loss: 0.4960 - accuracy: 0.8140 - val_loss: 0.6236 - val_accuracy: 0.7749
# Epoch 47/50
# 5488/5488 [==============================] - 1s 260us/step - loss: 0.4574 - accuracy: 0.8293 - val_loss: 0.5552 - val_accuracy: 0.8019
# Epoch 48/50
# 5488/5488 [==============================] - 1s 264us/step - loss: 0.4676 - accuracy: 0.8236 - val_loss: 0.7259 - val_accuracy: 0.7094
# Epoch 49/50
# 5488/5488 [==============================] - 1s 262us/step - loss: 0.4598 - accuracy: 0.8269 - val_loss: 0.5912 - val_accuracy: 0.7975
# Epoch 50/50
# 5488/5488 [==============================] - 1s 262us/step - loss: 0.4630 - accuracy: 0.8293 - val_loss: 0.5643 - val_accuracy: 0.7983

# %%
third.save("third.h5")

# %%
score, acc = third.evaluate(x_test, y_test,
                            batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 1716/1716 [==============================] - 0s 186us/step
# Test score: 0.5786949468381477
# Test accuracy: 0.7942890524864197

# %%
fourth = Sequential()

fourth.add(Conv2D(128, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
fourth.add(MaxPooling2D(pool_size=(2,2)))
fourth.add(Dropout(0.25))

fourth.add(Conv2D(64, (3,3), activation='relu'))
fourth.add(Conv2D(64, (3,3), activation='relu'))
fourth.add(MaxPooling2D(pool_size=(2,2)))
fourth.add(Dropout(0.25))

fourth.add(Conv2D(32, (3,3), activation='relu'))
fourth.add(Conv2D(32, (3,3), activation='relu'))
fourth.add(Dropout(0.25))

fourth.add(Flatten())
fourth.add(Dense(512,activation='relu'))
fourth.add(Dense(256,activation='relu'))
fourth.add(Dense(5,activation='softmax'))

fourth.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(fourth.summary())
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_158 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d_108 (MaxPoolin (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_159 (Conv2D)          (None, 13, 13, 64)        73792
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_109 (MaxPoolin (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 3, 3, 32)          18464
# _________________________________________________________________
# conv2d_162 (Conv2D)          (None, 1, 1, 32)          9248
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_106 (Dense)            (None, 512)               16896
# _________________________________________________________________
# dense_107 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_108 (Dense)            (None, 5)                 1285
# =================================================================
# Total params: 291,525
# Trainable params: 291,525
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
entrenar4 = fourth.fit(x_train,y_train,
                    batch_size=64,
                    epochs=50,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/50
# 5488/5488 [==============================] - 2s 312us/step - loss: 0.3636 - accuracy: 0.8615 - val_loss: 0.5444 - val_accuracy: 0.8150
# Epoch 2/50
# 5488/5488 [==============================] - 1s 227us/step - loss: 0.3455 - accuracy: 0.8641 - val_loss: 0.5415 - val_accuracy: 0.8128
# Epoch 3/50
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.3283 - accuracy: 0.8743 - val_loss: 0.5558 - val_accuracy: 0.8041
# Epoch 4/50
# 5488/5488 [==============================] - 1s 227us/step - loss: 0.3331 - accuracy: 0.8710 - val_loss: 0.5589 - val_accuracy: 0.8055
# Epoch 5/50
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.3442 - accuracy: 0.8681 - val_loss: 0.5602 - val_accuracy: 0.7910
# Epoch 6/50
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.3346 - accuracy: 0.8765 - val_loss: 0.6442 - val_accuracy: 0.7677
# Epoch 7/50
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.3318 - accuracy: 0.8732 - val_loss: 0.5814 - val_accuracy: 0.8055
# Epoch 8/50
# 5488/5488 [==============================] - 1s 229us/step - loss: 0.3211 - accuracy: 0.8750 - val_loss: 0.5503 - val_accuracy: 0.8019
# Epoch 9/50
# 5488/5488 [==============================] - 1s 226us/step - loss: 0.3142 - accuracy: 0.8768 - val_loss: 0.5734 - val_accuracy: 0.7932
# Epoch 10/50
# 5488/5488 [==============================] - 1s 224us/step - loss: 0.3150 - accuracy: 0.8796 - val_loss: 0.5617 - val_accuracy: 0.8034
# Epoch 11/50
# 5488/5488 [==============================] - 1s 225us/step - loss: 0.3120 - accuracy: 0.8801 - val_loss: 0.5845 - val_accuracy: 0.7881
# 5488/5488 [==============================] - 1s 217us/step - loss: 0.2224 - accuracy: 0.9145 - val_loss: 0.6389 - val_accuracy: 0.7917

# %%
fourth.save("fourth.h5")

# %%
score, acc = fourth.evaluate(x_test, y_test,
                            batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 1716/1716 [==============================] - 0s 159us/step
# Test score: 0.647662808567216
# Test accuracy: 0.8059440851211548

# %%
quinto = Sequential()

quinto.add(Conv2D(128, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
quinto.add(MaxPooling2D(pool_size=(2,2)))
quinto.add(Dropout(0.2))

quinto.add(Conv2D(64, (3,3), activation='relu'))
quinto.add(Conv2D(64, (3,3), activation='relu'))
quinto.add(MaxPooling2D(pool_size=(2,2)))
quinto.add(Dropout(0.2))

quinto.add(Conv2D(32, (3,3), activation='relu'))
quinto.add(Conv2D(32, (3,3), activation='relu'))
quinto.add(Dropout(0.2))

quinto.add(Flatten())
quinto.add(Dense(512,activation='relu'))
quinto.add(Dense(256,activation='relu'))
quinto.add(Dense(5,activation='softmax'))

quinto.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(quinto.summary())
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_163 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d_110 (MaxPoolin (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_164 (Conv2D)          (None, 13, 13, 64)        73792
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_111 (MaxPoolin (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_166 (Conv2D)          (None, 3, 3, 32)          18464
# _________________________________________________________________
# conv2d_167 (Conv2D)          (None, 1, 1, 32)          9248
# _________________________________________________________________
# dropout_112 (Dropout)        (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_109 (Dense)            (None, 512)               16896
# _________________________________________________________________
# dense_110 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_111 (Dense)            (None, 5)                 1285
# =================================================================
# Total params: 291,525
# Trainable params: 291,525
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
entrenar5 = quinto.fit(x_train,y_train,
                    batch_size=64,
                    epochs=50,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/50
# 5488/5488 [==============================] - 2s 287us/step - loss: 1.7175 - accuracy: 0.2759 - val_loss: 1.5190 - val_accuracy: 0.4064
# Epoch 2/50
# 5488/5488 [==============================] - 1s 232us/step - loss: 1.4796 - accuracy: 0.4098 - val_loss: 1.3190 - val_accuracy: 0.5513
# Epoch 3/50
# 5488/5488 [==============================] - 1s 232us/step - loss: 1.3385 - accuracy: 0.4852 - val_loss: 1.1991 - val_accuracy: 0.6038
# Epoch 4/50
# 5488/5488 [==============================] - 1s 229us/step - loss: 1.1772 - accuracy: 0.5525 - val_loss: 1.0787 - val_accuracy: 0.5594
# Epoch 43/50
# 5488/5488 [==============================] - 1s 228us/step - loss: 0.5307 - accuracy: 0.8050 - val_loss: 0.7604 - val_accuracy: 0.7363
# Epoch 44/50
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.5193 - accuracy: 0.8027 - val_loss: 0.7071 - val_accuracy: 0.7618
# Epoch 45/50
# 5488/5488 [==============================] - 1s 234us/step - loss: 0.5157 - accuracy: 0.8063 - val_loss: 0.6614 - val_accuracy: 0.7779
# Epoch 46/50
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.5205 - accuracy: 0.8019 - val_loss: 0.7424 - val_accuracy: 0.7393
# Epoch 47/50
# 5488/5488 [==============================] - 1s 229us/step - loss: 0.4944 - accuracy: 0.8181 - val_loss: 0.6959 - val_accuracy: 0.7640
# Epoch 48/50
# 5488/5488 [==============================] - 1s 233us/step - loss: 0.4806 - accuracy: 0.8194 - val_loss: 0.6492 - val_accuracy: 0.7859
# Epoch 49/50
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.4971 - accuracy: 0.8143 - val_loss: 0.6402 - val_accuracy: 0.7837
# Epoch 50/50
# 5488/5488 [==============================] - 1s 230us/step - loss: 0.4848 - accuracy: 0.8189 - val_loss: 0.6665 - val_accuracy: 0.7779

# %%
posibilidades = ['drawing','engraving','iconography','painting','sculpture']
for i in range(5):
    number = np.random.randint(1,7000)
    test_image = pruebax[number]
    #test_image = cv.imread('./test2.jpg')
    transformed = cv.resize(test_image,(32,32))
    plt.imshow(cv.cvtColor(test_image,cv.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
    print("GUESS: ",posibilidades[np.argmax(fourth.predict(np.expand_dims(transformed,0)))])
    print("REAL: ", posibilidades[pruebay[number]])
# Out:
# GUESS:  iconography
# REAL:  iconography
# GUESS:  iconography
# REAL:  iconography
# GUESS:  drawing
# REAL:  drawing
# GUESS:  iconography
# REAL:  iconography
# GUESS:  drawing
# REAL:  drawing

# %%
np.unique(pruebay,return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([1229,  844, 2310, 2364, 1938], dtype=int64))

# %%
filtros = []
for i in fourth.layers:
    if "conv" not in i.name:
        continue
    filters,bias = i.get_weights()
    filtros.append(filters)
    print(filters.shape)
# Out:
# (3, 3, 3, 128)
# (3, 3, 128, 64)
# (3, 3, 64, 64)
# (3, 3, 64, 32)
# (3, 3, 32, 32)

# %%
filters = filtros[0]
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
plt.imshow(filters[:,:,:,0][:,:,0],cmap='gray')

# %%
from keras.models import Model
#feature_model = Model(inputs=fourth.inputs, outputs=fourth.layers[2].output)

# %%
feature_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_158_input (InputLayer (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d_108 (MaxPoolin (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 15, 15, 128)       0
# =================================================================
# Total params: 3,584
# Trainable params: 3,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = feature_model.predict(np.expand_dims(cv.resize(cv.imread('./test.jpg'),(32,32)),0))

# %%
result.shape
# Out:
# (1, 15, 15, 128)

# %%
for i in range(128):
    plt.imshow(result[0,:,:,i],cmap="gray")
    plt.axis("off")
    plt.show()

# %%
from keras.models import load_model
ver = load_model("./fourth.h5")

# %%
fourth2 = Sequential()

fourth2.add(Conv2D(128, (3,3), activation='relu', input_shape=(x_train.shape[1:])))
fourth2.add(MaxPooling2D(pool_size=(2,2)))
fourth2.add(Dropout(0.25))

fourth2.add(Conv2D(64, (3,3), activation='relu'))
fourth2.add(Conv2D(64, (3,3), activation='relu'))
fourth2.add(MaxPooling2D(pool_size=(2,2)))
fourth2.add(Dropout(0.25))

fourth2.add(Conv2D(32, (3,3), activation='relu'))
fourth2.add(Conv2D(64, (3,3), activation='relu'))
fourth2.add(MaxPooling2D(pool_size=(2,2)))
fourth2.add(Dropout(0.25))

fourth2.add(Flatten())
fourth2.add(Dense(128,activation='relu'))
fourth2.add(Dense(128,activation='relu'))
fourth2.add(Dense(5,activation='softmax'))

fourth2.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

print(fourth2.summary())
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_126 (Conv2D)          (None, 62, 62, 128)       3584
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 29, 29, 64)        73792
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 27, 27, 64)        36928
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_129 (Conv2D)          (None, 11, 11, 32)        18464
# _________________________________________________________________
# conv2d_130 (Conv2D)          (None, 9, 9, 64)          18496
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dense_74 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_75 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 299,621
# Trainable params: 299,621
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
mayor = fourth2.fit(x_train,y_train,
                    batch_size=32,
                    epochs=75,
                    validation_split=0.2,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5488 samples, validate on 1373 samples
# Epoch 1/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.4675 - accuracy: 0.8198 - val_loss: 0.6083 - val_accuracy: 0.7808
# Epoch 2/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.4488 - accuracy: 0.8333 - val_loss: 0.6046 - val_accuracy: 0.7837
# Epoch 3/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.4422 - accuracy: 0.8382 - val_loss: 0.5817 - val_accuracy: 0.7830
# Epoch 4/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.4564 - accuracy: 0.8296 - val_loss: 0.5611 - val_accuracy: 0.7990
# Epoch 5/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.4408 - accuracy: 0.8316 - val_loss: 0.5809 - val_accuracy: 0.7866
# Epoch 6/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0
75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2621 - accuracy: 0.8963 - val_loss: 0.6519 - val_accuracy: 0.8055
# Epoch 57/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2611 - accuracy: 0.8994 - val_loss: 0.6647 - val_accuracy: 0.7939
# Epoch 58/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2389 - accuracy: 0.9071 - val_loss: 0.7000 - val_accuracy: 0.7902
# Epoch 59/75
# 5488/5488 [==============================] - 17s 3ms/step - loss: 0.2257 - accuracy: 0.9133 - val_loss: 0.7903 - val_accuracy: 0.7757
# Epoch 60/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2456 - accuracy: 0.9069 - val_loss: 0.7197 - val_accuracy: 0.7997
# Epoch 61/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2430 - accuracy: 0.9062 - val_loss: 0.7602 - val_accuracy: 0.7888
# Epoch 62/75
# 5488/5488 [==============================] - 16s 3ms/step - loss: 0.2399 - accuracy: 0.9105 - val_loss: 0.6707 - val_accuracy: 0.8012
# Epoch 63/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2431 - accuracy: 0.9043 - val_loss: 0.7036 - val_accuracy: 0.7873
# Epoch 64/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2405 - accuracy: 0.9094 - val_loss: 0.6860 - val_accuracy: 0.8084
# Epoch 65/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2242 - accuracy: 0.9140 - val_loss: 0.7936 - val_accuracy: 0.7953
# Epoch 66/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2294 - accuracy: 0.9122 - val_loss: 0.8004 - val_accuracy: 0.7902
# Epoch 67/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2166 - accuracy: 0.9156 - val_loss: 0.7863 - val_accuracy: 0.7924
# Epoch 68/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2381 - accuracy: 0.9107 - val_loss: 0.7947 - val_accuracy: 0.7881
# Epoch 69/75
# 5488/5488 [==============================] - 16s 3ms/step - loss: 0.2223 - accuracy: 0.9138 - val_loss: 0.7205 - val_accuracy: 0.7924
# Epoch 70/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2032 - accuracy: 0.9209 - val_loss: 0.7951 - val_accuracy: 0.7953
# Epoch 71/75
# 5488/5488 [==============================] - 16s 3ms/step - loss: 0.2280 - accuracy: 0.9151 - val_loss: 0.7851 - val_accuracy: 0.7895
# Epoch 72/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2153 - accuracy: 0.9189 - val_loss: 0.7546 - val_accuracy: 0.7873
# Epoch 73/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2032 - accuracy: 0.9233 - val_loss: 0.7169 - val_accuracy: 0.8034
# Epoch 74/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.1981 - accuracy: 0.9220 - val_loss: 0.7892 - val_accuracy: 0.8099
# Epoch 75/75
# 5488/5488 [==============================] - 15s 3ms/step - loss: 0.2172 - accuracy: 0.9180 - val_loss: 0.7122 - val_accuracy: 0.7953

# %%
outputs = []
for i in range(len(fourth2.layers)):
    if 'conv' in fourth2.layers[i].name:
        conv.append(fourth2.layers[i])
        print(i)
# Out:
# 0
# 3
# 4
# 7
# 8

# %%
sacar = Model(inputs=fourth2.inputs, outputs=fourth2.layers[0].output)

# %%
test = cv.imread('./test.jpg')
test = cv.cvtColor(test,cv.COLOR_BGR2RGB)
test = np.expand_dims(cv.resize(test,(64,64)),0)
test.shape
# Out:
# (1, 64, 64, 3)

# %%
features = sacar.predict(test)

# %%
features.shape
# Out:
# (1, 62, 62, 128)

# %%
for i in range(0,127):
    temp = features[0,:,:,i]
    plt.imshow(temp,cmap='gray')
    plt.show()
